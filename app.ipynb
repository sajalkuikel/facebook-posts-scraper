# %%
import pandas as pd
d = pd.read_json('./dataset/OrganicSarcasmNepal/facebook_posts.json')
d.head()
# Out:
#                                              post_id              page_id  \
# 0  pfbid0KDRea4oe2YXVQpXdgQiLyT5Z72PYQ8cDWgAqZLW5...  OrganicSarcasmNepal
# 1  pfbid02w7jX37SHpGyC3VWKNiJzENu6AHuTFp3iVeMkExu...  OrganicSarcasmNepal
# 2  pfbid028PFKms2imkAr8dQrhLy3CEqpEbqHJ4UNoXUaDEo...  OrganicSarcasmNepal
# 3  pfbid02d9KiAeVUXczqRxDDsEuxMkLhkc9a7dBfjHxs1s9...  OrganicSarcasmNepal
# 4  pfbid02vWTaPef5xEoZBvL5sLjR8MBNaCEa8ZYFtxnah84...  OrganicSarcasmNepal
#
#                                             post_url  \
# 0  https://www.facebook.com/OrganicSarcasmNepal/p...
# 1  https://www.facebook.com/OrganicSarcasmNepal/p...
# 2  https://www.facebook.com/OrganicSarcasmNepal/p...
# 3  https://www.facebook.com/OrganicSarcasmNepal/p...
# 4  https://www.facebook.com/OrganicSarcasmNepal/p...
#
#                                            post_text  \
# 0  नेपालमा लगानीको बाताबरण नै छैनThose who spent ...
# 1  The audacity of this fucking guy to retweet a ...
# ...

# %%
d [ ['post_text', 'image    '] ]
